# %%
from keras.engine import input_layer
import numpy as np
from matplotlib import pyplot as plt

import keras
from keras.models import Sequential 
from keras.layers import Dense
from keras.optimizers import RMSprop

#Function: cos(X) + √y
def f(x,y):
  return np.cos(x) + np.sqrt(y)

seed_value = 23439
samples = 50
show = 30

if show > samples:
  show = samples

np.random.seed(seed_value)
X = np.random.randint(low=0, high=10, size=(samples, 2))
Y_true = np.array([f(x[0],x[1]) for x in X])

model = Sequential();
#1
model.add(Dense(units=4, input_shape=(2,)))
model.add(Dense(units=3))
model.add(Dense(units=1))


print(model.summary())

model.compile(optimizer = RMSprop(), loss = 'mean_absolute_error')

history = model.fit(x = X, y = Y_true, batch_size = 2, epochs = 15)

plt.plot(history.history['loss'])
plt.show()

osx = [i for i in range(show)]

Y_pred = model.predict(X)

plt.plot(osx, Y_true[0:show], linewidth=5)
plt.plot(osx, Y_pred[0:show], color = 'red')
plt.show()
# Out:
# Model: "sequential_67"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_248 (Dense)           (None, 4)                 12
#
#  dense_249 (Dense)           (None, 3)                 15
#
#  dense_250 (Dense)           (None, 1)                 4
#
# ...
# Total params: 31
# Trainable params: 31
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/15
# 25/25 [==============================] - 1s 1ms/step - loss: 8.6038
# Epoch 2/15
# 25/25 [==============================] - 0s 2ms/step - loss: 7.0577
# Epoch 3/15
# 25/25 [==============================] - 0s 2ms/step - loss: 5.6909
# Epoch 4/15
# 25/25 [==============================] - 0s 1ms/step - loss: 4.4222
# Epoch 5/15
# 25/25 [==============================] - 0s 2ms/step - loss: 3.2638
# Epoch 6/15
# 25/25 [==============================] - 0s 2ms/step - loss: 2.1944
# Epoch 7/15
# ...

# %% [markdown]
# Poprawki

# %%
from keras.engine import input_layer
import numpy as np
from matplotlib import pyplot as plt

import keras
from keras.models import Sequential 
from keras.layers import Dense
from keras.optimizers import RMSprop

#Function: cos(X) + √y
def f(x,y):
  return np.cos(x) + np.sqrt(y)

seed_value = 23439
samples = 50
show = 50

if show > samples:
  show = samples

np.random.seed(seed_value)
X = np.random.randint(low=0, high=10, size=(samples, 2))
Y_true = np.array([f(x[0],x[1]) for x in X])

model = Sequential();

model.add(Dense(units=8, input_shape=(2,)))
model.add(Dense(units=6))
model.add(Dense(units=4))
model.add(Dense(units=2))
model.add(Dense(units=1))

print(model.summary())

adam = keras.optimizers.Adam(learning_rate=0.0001)
model.compile(optimizer = adam, loss = 'mean_absolute_error')

history = model.fit(x = X, y = Y_true, batch_size = 2, epochs = 40)

plt.plot(history.history['loss'])
plt.show()

osx = [i for i in range(show)]

Y_pred = model.predict(X)

plt.plot(osx, Y_true[0:show], linewidth=5)
plt.plot(osx, Y_pred[0:show], color = 'red')
plt.show()
# Out:
# Model: "sequential_55"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_190 (Dense)           (None, 8)                 24
#
#  dense_191 (Dense)           (None, 6)                 54
#
#  dense_192 (Dense)           (None, 4)                 28
#
#  dense_193 (Dense)           (None, 2)                 10
#
#  dense_194 (Dense)           (None, 1)                 3
#
# ...
# Total params: 119
# Trainable params: 119
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/40
# 25/25 [==============================] - 1s 2ms/step - loss: 2.4802
# Epoch 2/40
# 25/25 [==============================] - 0s 2ms/step - loss: 2.1174
# Epoch 3/40
# 25/25 [==============================] - 0s 2ms/step - loss: 1.7645
# Epoch 4/40
# 25/25 [==============================] - 0s 2ms/step - loss: 1.4642
# Epoch 5/40
# ...

# %% [markdown]
# 3

# %%
from keras.engine import input_layer
import numpy as np
from matplotlib import pyplot as plt

import keras
from keras.models import Sequential 
from keras.layers import Dense
from keras.optimizers import RMSprop

#Function: cos(X) + √y
def f(x,y):
  return np.cos(x) + np.sqrt(y)

seed_value = 23439
samples = 100
show = 50

if show > samples:
  show = samples

np.random.seed(seed_value)
X = np.random.randint(low=0, high=10, size=(samples, 2))
Y_true = np.array([f(x[0],x[1]) for x in X])

model = Sequential();

model.add(Dense(units=8, input_shape=(2,)))
model.add(Dense(units=6))
model.add(Dense(units=4))
model.add(Dense(units=2))
model.add(Dense(units=1))

print(model.summary())

adam = keras.optimizers.Adam(learning_rate=0.0001)
model.compile(optimizer = adam, loss = 'log_cosh')

history = model.fit(x = X, y = Y_true, batch_size = 4, epochs = 60)

plt.plot(history.history['loss'])
plt.show()

osx = [i for i in range(show)]

Y_pred = model.predict(X)

plt.plot(osx, Y_true[0:show], linewidth=5)
plt.plot(osx, Y_pred[0:show], color = 'red')
plt.show()
# Out:
# Model: "sequential_65"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_240 (Dense)           (None, 8)                 24
#
#  dense_241 (Dense)           (None, 6)                 54
#
#  dense_242 (Dense)           (None, 4)                 28
#
#  dense_243 (Dense)           (None, 2)                 10
#
#  dense_244 (Dense)           (None, 1)                 3
#
# ...
# Total params: 119
# Trainable params: 119
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/60
# 25/25 [==============================] - 1s 2ms/step - loss: 1.6150
# Epoch 2/60
# 25/25 [==============================] - 0s 2ms/step - loss: 0.3240
# Epoch 3/60
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2902
# Epoch 4/60
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2840
# Epoch 5/60
# ...

# %% [markdown]
# 4

# %%
from keras.engine import input_layer
import numpy as np
from matplotlib import pyplot as plt

import keras
from keras.models import Sequential 
from keras.layers import Dense
from keras.optimizers import RMSprop

#Function: cos(X) + √y
def f(x,y):
  return np.cos(x) + np.sqrt(y)

seed_value = 23439
samples = 100
show = 50

if show > samples:
  show = samples

np.random.seed(seed_value)
X = np.random.randint(low=0, high=10, size=(samples, 2))
Y_true = np.array([f(x[0],x[1]) for x in X])

model = Sequential();

model.add(Dense(units=8, input_shape=(2,)))
model.add(Dense(units=6))
model.add(Dense(units=4))
model.add(Dense(units=2))
model.add(Dense(units=1))

print(model.summary())

adam = keras.optimizers.Adam(learning_rate=0.0001)
model.compile(optimizer = RMSprop(), loss = 'huber_loss')

history = model.fit(x = X, y = Y_true, batch_size = 4, epochs = 60)

plt.plot(history.history['loss'])
plt.show()

osx = [i for i in range(show)]

Y_pred = model.predict(X)

plt.plot(osx, Y_true[0:show], linewidth=5)
plt.plot(osx, Y_pred[0:show], color = 'red')
plt.show()
# Out:
# Model: "sequential_64"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_235 (Dense)           (None, 8)                 24
#
#  dense_236 (Dense)           (None, 6)                 54
#
#  dense_237 (Dense)           (None, 4)                 28
#
#  dense_238 (Dense)           (None, 2)                 10
#
#  dense_239 (Dense)           (None, 1)                 3
#
# ...
# Total params: 119
# Trainable params: 119
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/60
# 25/25 [==============================] - 1s 2ms/step - loss: 0.6693
# Epoch 2/60
# 25/25 [==============================] - 0s 2ms/step - loss: 0.4010
# Epoch 3/60
# 25/25 [==============================] - 0s 2ms/step - loss: 0.3646
# Epoch 4/60
# 25/25 [==============================] - 0s 2ms/step - loss: 0.3388
# Epoch 5/60
# ...
